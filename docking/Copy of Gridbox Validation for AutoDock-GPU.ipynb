# %%
#@title #**1. Install The Required Softwares**
#@markdown Execute this cell first to download and install third-party softwares

import os, re, shutil, tqdm.notebook, subprocess, pandas as pd, numpy as np, copy
from google.colab import files
from xml.dom import minidom
from IPython.utils import io
from IPython.display import clear_output

os.environ['GPU_INCLUDE_PATH'] = '/usr/local/cuda/include'
os.environ['GPU_LIBRARY_PATH'] = '/usr/local/cuda/lib64'

TQDM_BAR_FORMAT = '{l_bar}{bar}| {n_fmt}/{total_fmt} [elapsed: {elapsed} remaining: {remaining}]'
try:
  with tqdm.notebook.tqdm(total = 100, bar_format = TQDM_BAR_FORMAT) as pbar:
    with io.capture_output() as captured:
      # %shell wget https://autodock.scripps.edu/wp-content/uploads/sites/56/2021/10/autodocksuite-4.2.6-x86_64Linux2.tar
      # %shell tar -xvf '/content/autodocksuite-4.2.6-x86_64Linux2.tar' -C '/content'
      pbar.update(15)

      # %shell pip install zipfile36
      from zipfile36 import ZipFile
      pbar.update(15)

      # %shell wget https://github.com/ccsb-scripps/AutoDock-GPU/archive/refs/heads/develop.zip -O autodock-gpu.zip
      # %shell unzip '/content/autodock-gpu.zip'
      os.chdir('AutoDock-GPU-develop')
      # %shell make DEVICE=CUDA
      pbar.update(20)

      # %cd /content
      # %shell wget -c https://ccsb.scripps.edu/download/532/ -O mgltools.tar.gz
      # %shell mkdir mgltools
      # %shell tar -xvzf mgltools.tar.gz -C mgltools --strip-components=1

      # %shell wget https://ccsb.scripps.edu/adfr/download/1038/ -O adfr.tar.gz
      # %shell tar -xf adfr.tar.gz
      # %shell mkdir adfr
      # %cd /content/ADFRsuite_x86_64Linux_1.0
      # %shell yes | ./install.sh -d /content/adfr
      # %cd /content
      pbar.update(30)

      # %cd mgltools
      # %shell ./install.sh
      pbar.update(10)

      # %shell pip install ipywidgets meeko
      from ipywidgets import widgets
      # %shell pip install rdkit
      from rdkit import Chem
      from rdkit.Chem import AllChem
      pbar.update(10)
except subprocess.CalledProcessError:
  print(captured)
  raise

working_dir = os.path.join('/content', 'working_dir')
os.mkdir(working_dir)
os.chdir(working_dir)
# Out:
#   0%|          | 0/100 [elapsed: 00:00 remaining: ?]

# %%
#@title #**2. Upload Receptor and Ligand File**
#@markdown Please upload the **receptor (PDB)** and **ligand (SDF)** simultaneously, then select what file being a receptor or a ligand
#@markdown **Note:** The file name should not contain any space

working_dir = os.path.join('/content', 'working_dir')
if (not os.path.isdir(working_dir)):
  os.mkdir(working_dir)
else:
  shutil.rmtree(working_dir)
  os.mkdir(working_dir)
os.chdir(working_dir)

receptor_name = ''
ligand_name = ''

uploaded_files = list(files.upload().keys())
clear_output()

receptor_input = widgets.Dropdown(
    options = uploaded_files,
    description = 'Receptor:',
    layout = widgets.Layout(margin = '0 0 20px 0')
)
display(receptor_input)

ligand_input = widgets.Dropdown(
    options = uploaded_files,
    description = 'Ligand:'
)
display(ligand_input)

button = widgets.Button(
    description = 'Select',
    layout = widgets.Layout(margin = '20px 0 20px 90px')
)
display(button)

receptor_label = widgets.Label(value = 'Receptor:')
display(receptor_label)
ligand_label = widgets.Label(value = 'Ligand:')
display(ligand_label)

def incorporate_names(b):
  global receptor_name, ligand_name
  receptor_name = receptor_input.value
  ligand_name = ligand_input.value
  receptor_label.value = 'Receptor: ' + receptor_name
  ligand_label.value = 'Ligand: ' + ligand_name

button.on_click(incorporate_names)
# Out:
# Dropdown(description='Receptor:', layout=Layout(margin='0 0 20px 0'), options=('ligand.sdf', 'receptor.pdb'), …
# Dropdown(description='Ligand:', options=('ligand.sdf', 'receptor.pdb'), value='ligand.sdf')
# Button(description='Select', layout=Layout(margin='20px 0 20px 90px'), style=ButtonStyle())
# Label(value='Receptor:')
# Label(value='Ligand:')

# %%
#@title #**3. Convert Receptor and Ligand File to PDBQT Format**

os.chdir(working_dir)

for f in os.listdir():
  if((f != receptor_name) and (f != ligand_name) and (not os.path.isdir(f))):
    os.remove(f)

receptor_pdbqt = re.split('\.', receptor_name)[0] + '.pdbqt'
ligand_pdbqt = re.split('\.', ligand_name)[0] + '.pdbqt'

print(f'Convert {receptor_name} to PDBQT format')
res_receptor = os.system(f'/content/adfr/bin/prepare_receptor -r {receptor_name}')

print(f'Convert {ligand_name} to PDBQT format')
res_ligand = os.system(f'mk_prepare_ligand.py -i {ligand_name} -o {ligand_pdbqt}')
# Out:
# Convert receptor.pdb to PDBQT format
# Convert ligand.sdf to PDBQT format

# %%
#@title #**4. Find Ligand Center Point**
#@markdown Center point of x, y, z dimension will be used in the docking process.
#@markdown Once this cell has been executed, the center point of the ligand will be displayed as center_x, center_y, and center_z

os.chdir(working_dir)

supplier = Chem.SDMolSupplier(ligand_name, removeHs=False)
mol = supplier[0]
conf = mol.GetConformer()

coords = np.array([list(conf.GetAtomPosition(i)) for i in range(mol.GetNumAtoms())])
center_x, center_y, center_z = coords.mean(axis=0)

print(f'Center of coordinates: x={center_x}, y={center_y}, z={center_z}')
# Out:
# Center of coordinates: x=11.07394411764706, y=13.791338235294116, z=17.3417

# %%
#@title #**5. Specify Gridbox Dimension**
#@markdown Specify the minimum and maximum size of the gridbox, and the stride

gridbox_min = 15 #@param {type:'integer'}
gridbox_max = 65 #@param {type:'integer'}
stride = 1 #@param {type:'integer'}

# %%
#@title #**5. Generate GPF file for each ligand**
#@markdown This will generate GPF folder contains different folders for each gridbox size

gpf_dir = os.path.join(working_dir, 'gpf')
if (not os.path.isdir(gpf_dir)):
  os.mkdir(gpf_dir)
else:
  shutil.rmtree(gpf_dir)
  os.mkdir(gpf_dir)

for size in range(gridbox_min, gridbox_max + 1, stride):
  cld = os.path.join(gpf_dir, str(size))
  os.mkdir(cld)

  shutil.copyfile(f'./{ligand_pdbqt}', f'{cld}/{ligand_pdbqt}')
  shutil.copyfile(f'./{receptor_pdbqt}', f'{cld}/{receptor_pdbqt}')

  os.chdir(cld) # Move to current ligand directory

  npts = f'npts=\'{size},{size},{size}\''
  gridcenter = f'gridcenter=\'{center_x},{center_y},{center_z}\''
  os.system(f'/content/mgltools/bin/pythonsh /content/mgltools/MGLToolsPckgs/AutoDockTools/Utilities24/prepare_gpf4.py -l {ligand_pdbqt} -r {receptor_pdbqt} -p {npts} -p {gridcenter}')

  os.chdir(working_dir) # Move back to working directory

# %%
#@title #**6. Run Autogrid4**
#@markdown Autogrid4 will generate all files needed for docking step

receptor_noext = receptor_name.split('.')[0]
gpf_file = receptor_noext + '.gpf'
gpf_log = receptor_noext + '.glg'

for lf in os.listdir(gpf_dir):
  os.chdir(f'{gpf_dir}/{lf}') # Move to individual ligand folder

  subprocess.run(['/content/x86_64Linux2/autogrid4', '-p', gpf_file, '-l', gpf_log])

os.chdir(working_dir) # Move back to working directory
clear_output()

# %%
#@title #**7. Run AutoDock-GPU**
#@markdown Run this cell to start gridbox validation

result_dir = os.path.join(working_dir, 'result')
if (not os.path.isdir(result_dir)):
  os.mkdir(result_dir)
else:
  shutil.rmtree(result_dir)
  os.mkdir(result_dir)

for size in range(gridbox_min, gridbox_max + 1, stride):
  cld = os.path.join(result_dir, str(size))
  os.mkdir(cld)

recap = []

for size in os.listdir(gpf_dir):
  result = subprocess.run([
      '/content/AutoDock-GPU-develop/bin/autodock_gpu_128wi',
      '--ffile', f'{gpf_dir}/{size}/{receptor_noext}.maps.fld',
      '--lfile', f'{gpf_dir}/{size}/{ligand_pdbqt}',
      '--resnam', 'output',
      '--xmloutput', '1',
      '--gbest', '1',
      '--nrun', '100',
      '--psize', '100',
      # '--gfpop', '1',
      # '--npdb', '1',
      '--derivtype', '-T'
    ], capture_output=True, text=True)

  if (os.path.exists(f'{working_dir}/output-best.pdbqt')):
    naming = f'gridbox_x{size}_y{size}_z{size}'

    shutil.move('output-best.pdbqt', f'{result_dir}/{size}/{naming}.pdbqt')
    shutil.move('output.dlg', f'{result_dir}/{size}/{naming}.dlg')
    shutil.move('output.xml', f'{result_dir}/{size}/{naming}.xml')

    os.system(f'mk_export.py {result_dir}/{size}/{naming}.pdbqt -s {result_dir}/{size}/{naming}.sdf')

    match = re.search(r"best inter \+ intra\s+(-?\d+\.\d+)\s+kcal/mol", result.stdout, re.IGNORECASE)
    recap.append([f'{size}', float(match.group(1))])

    print(f'Succeed running for gridbox {size}^3')
  else:
    print(f'Cannot running for gridbox {size}^3')

# clear_output()
# Out:
# Succeed running for gridbox 59^3
# Succeed running for gridbox 29^3
# Succeed running for gridbox 19^3
# Succeed running for gridbox 64^3
# Succeed running for gridbox 27^3
# Succeed running for gridbox 24^3
# Succeed running for gridbox 30^3
# Succeed running for gridbox 31^3
# Succeed running for gridbox 58^3
# Succeed running for gridbox 17^3
# Succeed running for gridbox 47^3
# Succeed running for gridbox 45^3
# Succeed running for gridbox 22^3
# Succeed running for gridbox 51^3
# Succeed running for gridbox 50^3
# Succeed running for gridbox 37^3
# Succeed running for gridbox 20^3
# Succeed running for gridbox 55^3
# Succeed running for gridbox 35^3
# Succeed running for gridbox 53^3
# Succeed running for gridbox 39^3
# Succeed running for gridbox 38^3
# Succeed running for gridbox 23^3
# Succeed running for gridbox 18^3
# Succeed running for gridbox 25^3
# Succeed running for gridbox 15^3
# Succeed running for gridbox 56^3
# Succeed running for gridbox 41^3
# Succeed running for gridbox 26^3
# Succeed running for gridbox 34^3
# Succeed running for gridbox 65^3
# Succeed running for gridbox 32^3
# Succeed running for gridbox 44^3
# Succeed running for gridbox 40^3
# Succeed running for gridbox 33^3
# Succeed running for gridbox 16^3
# Succeed running for gridbox 63^3
# Succeed running for gridbox 48^3
# Succeed running for gridbox 57^3
# Succeed running for gridbox 42^3
# Succeed running for gridbox 60^3
# Succeed running for gridbox 52^3
# Succeed running for gridbox 49^3
# Succeed running for gridbox 43^3
# Succeed running for gridbox 61^3
# Succeed running for gridbox 36^3
# Succeed running for gridbox 28^3
# Succeed running for gridbox 46^3
# Succeed running for gridbox 62^3
# Succeed running for gridbox 54^3
# Succeed running for gridbox 21^3

# %%
#@title #**8. Calculate RMSD**
#@markdown After running this cell, there would be zip-formatted archive contains
#@markdown files that automatically will be downloaded

new_recap = copy.deepcopy(recap)

for idx, gridbox in enumerate(recap):
  size = gridbox[0]
  sdf = f'gridbox_x{size}_y{size}_z{size}.sdf'
  shutil.copyfile(f'{result_dir}/{size}/{sdf}', f'{sdf}')

  mol1 = Chem.SDMolSupplier(ligand_name, removeHs=False)[0]
  mol2 = Chem.SDMolSupplier(sdf, removeHs=False)[0]

  rmsd = AllChem.GetBestRMS(mol1, mol2)
  new_recap[idx].append(f'{rmsd:.4f}')

  os.remove(sdf)

recap_df = pd.DataFrame(new_recap, columns=['Gridbox Size (Å^3)', 'Binding Energy (kcal/mol)', 'RMSD (Å)']).sort_values(by=['RMSD (Å)'])
recap_df.to_csv('RMSD evaluation for each gridbox size.csv', index=False)

# !zip -r gridbox_validation_autodock_gpu.zip ./*
files.download(os.path.join(working_dir, 'gridbox_validation_autodock_gpu.zip'))
# Out:
#   adding: gpf/ (stored 0%)
#   adding: gpf/59/ (stored 0%)
#   adding: gpf/59/receptor.gpf (deflated 64%)
#   adding: gpf/59/receptor.maps.fld (deflated 65%)
#   adding: gpf/59/receptor.C.map (deflated 57%)
#   adding: gpf/59/receptor.d.map (deflated 71%)
#   adding: gpf/59/receptor.OA.map (deflated 58%)
#   adding: gpf/59/ligand.pdbqt (deflated 70%)
#   adding: gpf/59/receptor.pdbqt (deflated 73%)
#   adding: gpf/59/receptor.glg (deflated 85%)
#   adding: gpf/59/receptor.NA.map (deflated 57%)
#   adding: gpf/59/receptor.N.map (deflated 57%)
#   adding: gpf/59/receptor.e.map (deflated 67%)
#   adding: gpf/59/receptor.maps.xyz (deflated 3%)
#   adding: gpf/59/receptor.A.map (deflated 57%)
#   adding: gpf/59/receptor.HD.map (deflated 63%)
#   adding: gpf/29/ (stored 0%)
#   adding: gpf/29/receptor.gpf (deflated 64%)
#   adding: gpf/29/receptor.maps.fld (deflated 65%)
#   adding: gpf/29/receptor.C.map (deflated 56%)
#   adding: gpf/29/receptor.d.map (deflated 72%)
#   adding: gpf/29/receptor.OA.map (deflated 57%)
#   adding: gpf/29/ligand.pdbqt (deflated 70%)
#   adding: gpf/29/receptor.pdbqt (deflated 73%)
#   adding: gpf/29/receptor.glg (deflated 85%)
#   adding: gpf/29/receptor.NA.map (deflated 57%)
#   adding: gpf/29/receptor.N.map (deflated 57%)
#   adding: gpf/29/receptor.e.map (deflated 69%)
#   adding: gpf/29/receptor.maps.xyz (deflated 5%)
#   adding: gpf/29/receptor.A.map (deflated 56%)
#   adding: gpf/29/receptor.HD.map (deflated 64%)
#   adding: gpf/19/ (stored 0%)
#   adding: gpf/19/receptor.gpf (deflated 64%)
#   adding: gpf/19/receptor.maps.fld (deflated 65%)
#   adding: gpf/19/receptor.C.map (deflated 59%)
#   adding: gpf/19/receptor.d.map (deflated 72%)
#   adding: gpf/19/receptor.OA.map (deflated 62%)
#   adding: gpf/19/ligand.pdbqt (deflated 70%)
#   adding: gpf/19/receptor.pdbqt (deflated 73%)
#   adding: gpf/19/receptor.glg (deflated 85%)
#   adding: gpf/19/receptor.NA.map (deflated 61%)
#   adding: gpf/19/receptor.N.map (deflated 61%)
#   adding: gpf/19/receptor.e.map (deflated 73%)
#   adding: gpf/19/receptor.maps.xyz (deflated 7%)
#   adding: gpf/19/receptor.A.map (deflated 59%)
#   adding: gpf/19/receptor.HD.map (deflated 71%)
#   adding: gpf/64/ (stored 0%)
#   adding: gpf/64/receptor.gpf (deflated 64%)
#   adding: gpf/64/receptor.maps.fld (deflated 65%)
#   adding: gpf/64/receptor.C.map (deflated 57%)
#   adding: gpf/64/receptor.d.map (deflated 71%)
#   adding: gpf/64/receptor.OA.map (deflated 58%)
#   adding: gpf/64/ligand.pdbqt (deflated 70%)
#   adding: gpf/64/receptor.pdbqt (deflated 73%)
#   adding: gpf/64/receptor.glg (deflated 85%)
#   adding: gpf/64/receptor.NA.map (deflated 58%)
#   adding: gpf/64/receptor.N.map (deflated 58%)
#   adding: gpf/64/receptor.e.map (deflated 67%)
#   adding: gpf/64/receptor.maps.xyz (deflated 8%)
#   adding: gpf/64/receptor.A.map (deflated 57%)
#   adding: gpf/64/receptor.HD.map (deflated 64%)
#   adding: gpf/27/ (stored 0%)
#   adding: gpf/27/receptor.gpf (deflated 64%)
#   adding: gpf/27/receptor.maps.fld (deflated 65%)
#   adding: gpf/27/receptor.C.map (deflated 56%)
#   adding: gpf/27/receptor.d.map (deflated 72%)
#   adding: gpf/27/receptor.OA.map (deflated 58%)
#   adding: gpf/27/ligand.pdbqt (deflated 70%)
#   adding: gpf/27/receptor.pdbqt (deflated 73%)
#   adding: gpf/27/receptor.glg (deflated 85%)
#   adding: gpf/27/receptor.NA.map (deflated 57%)
#   adding: gpf/27/receptor.N.map (deflated 57%)
#   adding: gpf/27/receptor.e.map (deflated 70%)
#   adding: gpf/27/receptor.maps.xyz (deflated 5%)
#   adding: gpf/27/receptor.A.map (deflated 56%)
#   adding: gpf/27/receptor.HD.map (deflated 65%)
#   adding: gpf/24/ (stored 0%)
#   adding: gpf/24/receptor.gpf (deflated 64%)
#   adding: gpf/24/receptor.maps.fld (deflated 65%)
#   adding: gpf/24/receptor.C.map (deflated 57%)
#   adding: gpf/24/receptor.d.map (deflated 72%)
#   adding: gpf/24/receptor.OA.map (deflated 59%)
#   adding: gpf/24/ligand.pdbqt (deflated 70%)
#   adding: gpf/24/receptor.pdbqt (deflated 73%)
#   adding: gpf/24/receptor.glg (deflated 85%)
#   adding: gpf/24/receptor.NA.map (deflated 58%)
#   adding: gpf/24/receptor.N.map (deflated 58%)
#   adding: gpf/24/receptor.e.map (deflated 71%)
#   adding: gpf/24/receptor.maps.xyz (deflated 13%)
#   adding: gpf/24/receptor.A.map (deflated 57%)
#   adding: gpf/24/receptor.HD.map (deflated 66%)
#   adding: gpf/30/ (stored 0%)
#   adding: gpf/30/receptor.gpf (deflated 64%)
#   adding: gpf/30/receptor.maps.fld (deflated 65%)
#   adding: gpf/30/receptor.C.map (deflated 56%)
#   adding: gpf/30/receptor.d.map (deflated 72%)
#   adding: gpf/30/receptor.OA.map (deflated 57%)
#   adding: gpf/30/ligand.pdbqt (deflated 70%)
#   adding: gpf/30/receptor.pdbqt (deflated 73%)
#   adding: gpf/30/receptor.glg (deflated 85%)
#   adding: gpf/30/receptor.NA.map (deflated 57%)
#   adding: gpf/30/receptor.N.map (deflated 57%)
#   adding: gpf/30/receptor.e.map (deflated 68%)
#   adding: gpf/30/receptor.maps.xyz (deflated 5%)
#   adding: gpf/30/receptor.A.map (deflated 56%)
#   adding: gpf/30/receptor.HD.map (deflated 63%)
#   adding: gpf/31/ (stored 0%)
#   adding: gpf/31/receptor.gpf (deflated 64%)
#   adding: gpf/31/receptor.maps.fld (deflated 65%)
#   adding: gpf/31/receptor.C.map (deflated 56%)
#   adding: gpf/31/receptor.d.map (deflated 72%)
#   adding: gpf/31/receptor.OA.map (deflated 57%)
#   adding: gpf/31/ligand.pdbqt (deflated 70%)
#   adding: gpf/31/receptor.pdbqt (deflated 73%)
#   adding: gpf/31/receptor.glg (deflated 85%)
#   adding: gpf/31/receptor.NA.map (deflated 57%)
#   adding: gpf/31/receptor.N.map (deflated 57%)
#   adding: gpf/31/receptor.e.map (deflated 68%)
#   adding: gpf/31/receptor.maps.xyz (deflated 5%)
#   adding: gpf/31/receptor.A.map (deflated 56%)
#   adding: gpf/31/receptor.HD.map (deflated 63%)
#   adding: gpf/58/ (stored 0%)
#   adding: gpf/58/receptor.gpf (deflated 64%)
#   adding: gpf/58/receptor.maps.fld (deflated 65%)
#   adding: gpf/58/receptor.C.map (deflated 57%)
#   adding: gpf/58/receptor.d.map (deflated 71%)
#   adding: gpf/58/receptor.OA.map (deflated 58%)
#   adding: gpf/58/ligand.pdbqt (deflated 70%)
#   adding: gpf/58/receptor.pdbqt (deflated 73%)
#   adding: gpf/58/receptor.glg (deflated 85%)
#   adding: gpf/58/receptor.NA.map (deflated 57%)
#   adding: gpf/58/receptor.N.map (deflated 57%)
#   adding: gpf/58/receptor.e.map (deflated 67%)
#   adding: gpf/58/receptor.maps.xyz (deflated 3%)
#   adding: gpf/58/receptor.A.map (deflated 57%)
#   adding: gpf/58/receptor.HD.map (deflated 63%)
#   adding: gpf/17/ (stored 0%)
#   adding: gpf/17/receptor.gpf (deflated 64%)
#   adding: gpf/17/receptor.maps.fld (deflated 65%)
#   adding: gpf/17/receptor.C.map (deflated 60%)
#   adding: gpf/17/receptor.d.map (deflated 72%)
#   adding: gpf/17/receptor.OA.map (deflated 63%)
#   adding: gpf/17/ligand.pdbqt (deflated 70%)
#   adding: gpf/17/receptor.pdbqt (deflated 73%)
#   adding: gpf/17/receptor.glg (deflated 85%)
#   adding: gpf/17/receptor.NA.map (deflated 62%)
#   adding: gpf/17/receptor.N.map (deflated 62%)
#   adding: gpf/17/receptor.e.map (deflated 74%)
#   adding: gpf/17/receptor.maps.xyz (deflated 17%)
#   adding: gpf/17/receptor.A.map (deflated 60%)
#   adding: gpf/17/receptor.HD.map (deflated 74%)
#   adding: gpf/47/ (stored 0%)
#   adding: gpf/47/receptor.gpf (deflated 64%)
#   adding: gpf/47/receptor.maps.fld (deflated 65%)
#   adding: gpf/47/receptor.C.map (deflated 56%)
#   adding: gpf/47/receptor.d.map (deflated 72%)
#   adding: gpf/47/receptor.OA.map (deflated 57%)
#   adding: gpf/47/ligand.pdbqt (deflated 70%)
#   adding: gpf/47/receptor.pdbqt (deflated 73%)
#   adding: gpf/47/receptor.glg (deflated 85%)
#   adding: gpf/47/receptor.NA.map (deflated 56%)
#   adding: gpf/47/receptor.N.map (deflated 56%)
#   adding: gpf/47/receptor.e.map (deflated 67%)
#   adding: gpf/47/receptor.maps.xyz (deflated 3%)
#   adding: gpf/47/receptor.A.map (deflated 56%)
#   adding: gpf/47/receptor.HD.map (deflated 62%)
#   adding: gpf/45/ (stored 0%)
#   adding: gpf/45/receptor.gpf (deflated 64%)
#   adding: gpf/45/receptor.maps.fld (deflated 65%)
#   adding: gpf/45/receptor.C.map (deflated 56%)
#   adding: gpf/45/receptor.d.map (deflated 72%)
#   adding: gpf/45/receptor.OA.map (deflated 57%)
#   adding: gpf/45/ligand.pdbqt (deflated 70%)
#   adding: gpf/45/receptor.pdbqt (deflated 73%)
#   adding: gpf/45/receptor.glg (deflated 85%)
#   adding: gpf/45/receptor.NA.map (deflated 56%)
#   adding: gpf/45/receptor.N.map (deflated 56%)
#   adding: gpf/45/receptor.e.map (deflated 67%)
#   adding: gpf/45/receptor.maps.xyz (stored 0%)
#   adding: gpf/45/receptor.A.map (deflated 56%)
#   adding: gpf/45/receptor.HD.map (deflated 61%)
#   adding: gpf/22/ (stored 0%)
#   adding: gpf/22/receptor.gpf (deflated 64%)
#   adding: gpf/22/receptor.maps.fld (deflated 65%)
#   adding: gpf/22/receptor.C.map (deflated 57%)
#   adding: gpf/22/receptor.d.map (deflated 72%)
#   adding: gpf/22/receptor.OA.map (deflated 60%)
#   adding: gpf/22/ligand.pdbqt (deflated 70%)
#   adding: gpf/22/receptor.pdbqt (deflated 73%)
#   adding: gpf/22/receptor.glg (deflated 85%)
#   adding: gpf/22/receptor.NA.map (deflated 59%)
#   adding: gpf/22/receptor.N.map (deflated 59%)
#   adding: gpf/22/receptor.e.map (deflated 71%)
#   adding: gpf/22/receptor.maps.xyz (deflated 5%)
#   adding: gpf/22/receptor.A.map (deflated 57%)
#   adding: gpf/22/receptor.HD.map (deflated 68%)
#   adding: gpf/51/ (stored 0%)
#   adding: gpf/51/receptor.gpf (deflated 64%)
#   adding: gpf/51/receptor.maps.fld (deflated 65%)
#   adding: gpf/51/receptor.C.map (deflated 56%)
#   adding: gpf/51/receptor.d.map (deflated 72%)
#   adding: gpf/51/receptor.OA.map (deflated 57%)
#   adding: gpf/51/ligand.pdbqt (deflated 70%)
#   adding: gpf/51/receptor.pdbqt (deflated 73%)
#   adding: gpf/51/receptor.glg (deflated 85%)
#   adding: gpf/51/receptor.NA.map (deflated 57%)
#   adding: gpf/51/receptor.N.map (deflated 57%)
#   adding: gpf/51/receptor.e.map (deflated 67%)
#   adding: gpf/51/receptor.maps.xyz (deflated 3%)
#   adding: gpf/51/receptor.A.map (deflated 56%)
#   adding: gpf/51/receptor.HD.map (deflated 62%)
#   adding: gpf/50/ (stored 0%)
#   adding: gpf/50/receptor.gpf (deflated 64%)
#   adding: gpf/50/receptor.maps.fld (deflated 65%)
#   adding: gpf/50/receptor.C.map (deflated 56%)
#   adding: gpf/50/receptor.d.map (deflated 72%)
#   adding: gpf/50/receptor.OA.map (deflated 57%)
#   adding: gpf/50/ligand.pdbqt (deflated 70%)
#   adding: gpf/50/receptor.pdbqt (deflated 73%)
#   adding: gpf/50/receptor.glg (deflated 85%)
#   adding: gpf/50/receptor.NA.map (deflated 57%)
#   adding: gpf/50/receptor.N.map (deflated 57%)
#   adding: gpf/50/receptor.e.map (deflated 67%)
#   adding: gpf/50/receptor.maps.xyz (deflated 3%)
#   adding: gpf/50/receptor.A.map (deflated 56%)
#   adding: gpf/50/receptor.HD.map (deflated 62%)
#   adding: gpf/37/ (stored 0%)
#   adding: gpf/37/receptor.gpf (deflated 64%)
#   adding: gpf/37/receptor.maps.fld (deflated 65%)
#   adding: gpf/37/receptor.C.map (deflated 56%)
#   adding: gpf/37/receptor.d.map (deflated 72%)
#   adding: gpf/37/receptor.OA.map (deflated 56%)
#   adding: gpf/37/ligand.pdbqt (deflated 70%)
#   adding: gpf/37/receptor.pdbqt (deflated 73%)
#   adding: gpf/37/receptor.glg (deflated 85%)
#   adding: gpf/37/receptor.NA.map (deflated 56%)
#   adding: gpf/37/receptor.N.map (deflated 56%)
#   adding: gpf/37/receptor.e.map (deflated 67%)
#   adding: gpf/37/receptor.maps.xyz (deflated 3%)
#   adding: gpf/37/receptor.A.map (deflated 56%)
#   adding: gpf/37/receptor.HD.map (deflated 62%)
#   adding: gpf/20/ (stored 0%)
#   adding: gpf/20/receptor.gpf (deflated 64%)
#   adding: gpf/20/receptor.maps.fld (deflated 65%)
#   adding: gpf/20/receptor.C.map (deflated 58%)
#   adding: gpf/20/receptor.d.map (deflated 72%)
#   adding: gpf/20/receptor.OA.map (deflated 61%)
#   adding: gpf/20/ligand.pdbqt (deflated 70%)
#   adding: gpf/20/receptor.pdbqt (deflated 73%)
#   adding: gpf/20/receptor.glg (deflated 85%)
#   adding: gpf/20/receptor.NA.map (deflated 60%)
#   adding: gpf/20/receptor.N.map (deflated 60%)
#   adding: gpf/20/receptor.e.map (deflated 72%)
#   adding: gpf/20/receptor.maps.xyz (deflated 5%)
#   adding: gpf/20/receptor.A.map (deflated 58%)
#   adding: gpf/20/receptor.HD.map (deflated 69%)
#   adding: gpf/55/ (stored 0%)
#   adding: gpf/55/receptor.gpf (deflated 64%)
#   adding: gpf/55/receptor.maps.fld (deflated 65%)
#   adding: gpf/55/receptor.C.map (deflated 56%)
#   adding: gpf/55/receptor.d.map (deflated 71%)
#   adding: gpf/55/receptor.OA.map (deflated 57%)
#   adding: gpf/55/ligand.pdbqt (deflated 70%)
#   adding: gpf/55/receptor.pdbqt (deflated 73%)
#   adding: gpf/55/receptor.glg (deflated 85%)
#   adding: gpf/55/receptor.NA.map (deflated 57%)
#   adding: gpf/55/receptor.N.map (deflated 57%)
#   adding: gpf/55/receptor.e.map (deflated 67%)
#   adding: gpf/55/receptor.maps.xyz (deflated 3%)
#   adding: gpf/55/receptor.A.map (deflated 56%)
#   adding: gpf/55/receptor.HD.map (deflated 63%)
#   adding: gpf/35/ (stored 0%)
#   adding: gpf/35/receptor.gpf (deflated 64%)
#   adding: gpf/35/receptor.maps.fld (deflated 65%)
#   adding: gpf/35/receptor.C.map (deflated 56%)
#   adding: gpf/35/receptor.d.map (deflated 72%)
#   adding: gpf/35/receptor.OA.map (deflated 57%)
#   adding: gpf/35/ligand.pdbqt (deflated 70%)
#   adding: gpf/35/receptor.pdbqt (deflated 73%)
#   adding: gpf/35/receptor.glg (deflated 85%)
#   adding: gpf/35/receptor.NA.map (deflated 56%)
#   adding: gpf/35/receptor.N.map (deflated 56%)
#   adding: gpf/35/receptor.e.map (deflated 68%)
#   adding: gpf/35/receptor.maps.xyz (deflated 3%)
#   adding: gpf/35/receptor.A.map (deflated 56%)
#   adding: gpf/35/receptor.HD.map (deflated 62%)
#   adding: gpf/53/ (stored 0%)
#   adding: gpf/53/receptor.gpf (deflated 64%)
#   adding: gpf/53/receptor.maps.fld (deflated 65%)
#   adding: gpf/53/receptor.C.map (deflated 56%)
#   adding: gpf/53/receptor.d.map (deflated 71%)
#   adding: gpf/53/receptor.OA.map (deflated 57%)
#   adding: gpf/53/ligand.pdbqt (deflated 70%)
#   adding: gpf/53/receptor.pdbqt (deflated 73%)
#   adding: gpf/53/receptor.glg (deflated 85%)
#   adding: gpf/53/receptor.NA.map (deflated 57%)
#   adding: gpf/53/receptor.N.map (deflated 57%)
#   adding: gpf/53/receptor.e.map (deflated 66%)
#   adding: gpf/53/receptor.maps.xyz (deflated 3%)
#   adding: gpf/53/receptor.A.map (deflated 56%)
#   adding: gpf/53/receptor.HD.map (deflated 62%)
#   adding: gpf/39/ (stored 0%)
#   adding: gpf/39/receptor.gpf (deflated 64%)
#   adding: gpf/39/receptor.maps.fld (deflated 65%)
#   adding: gpf/39/receptor.C.map (deflated 56%)
#   adding: gpf/39/receptor.d.map (deflated 72%)
#   adding: gpf/39/receptor.OA.map (deflated 56%)
#   adding: gpf/39/ligand.pdbqt (deflated 70%)
#   adding: gpf/39/receptor.pdbqt (deflated 73%)
#   adding: gpf/39/receptor.glg (deflated 85%)
#   adding: gpf/39/receptor.NA.map (deflated 56%)
#   adding: gpf/39/receptor.N.map (deflated 56%)
#   adding: gpf/39/receptor.e.map (deflated 67%)
#   adding: gpf/39/receptor.maps.xyz (deflated 5%)
#   adding: gpf/39/receptor.A.map (deflated 56%)
#   adding: gpf/39/receptor.HD.map (deflated 61%)
#   adding: gpf/38/ (stored 0%)
#   adding: gpf/38/receptor.gpf (deflated 64%)
#   adding: gpf/38/receptor.maps.fld (deflated 65%)
#   adding: gpf/38/receptor.C.map (deflated 56%)
#   adding: gpf/38/receptor.d.map (deflated 72%)
#   adding: gpf/38/receptor.OA.map (deflated 56%)
#   adding: gpf/38/ligand.pdbqt (deflated 70%)
#   adding: gpf/38/receptor.pdbqt (deflated 73%)
#   adding: gpf/38/receptor.glg (deflated 85%)
#   adding: gpf/38/receptor.NA.map (deflated 56%)
#   adding: gpf/38/receptor.N.map (deflated 56%)
#   adding: gpf/38/receptor.e.map (deflated 67%)
#   adding: gpf/38/receptor.maps.xyz (deflated 5%)
#   adding: gpf/38/receptor.A.map (deflated 56%)
#   adding: gpf/38/receptor.HD.map (deflated 61%)
#   adding: gpf/23/ (stored 0%)
#   adding: gpf/23/receptor.gpf (deflated 64%)
#   adding: gpf/23/receptor.maps.fld (deflated 65%)
#   adding: gpf/23/receptor.C.map (deflated 57%)
#   adding: gpf/23/receptor.d.map (deflated 72%)
#   adding: gpf/23/receptor.OA.map (deflated 60%)
#   adding: gpf/23/ligand.pdbqt (deflated 70%)
#   adding: gpf/23/receptor.pdbqt (deflated 73%)
#   adding: gpf/23/receptor.glg (deflated 85%)
#   adding: gpf/23/receptor.NA.map (deflated 59%)
#   adding: gpf/23/receptor.N.map (deflated 59%)
#   adding: gpf/23/receptor.e.map (deflated 71%)
#   adding: gpf/23/receptor.maps.xyz (deflated 5%)
#   adding: gpf/23/receptor.A.map (deflated 57%)
#   adding: gpf/23/receptor.HD.map (deflated 68%)
#   adding: gpf/18/ (stored 0%)
#   adding: gpf/18/receptor.gpf (deflated 64%)
#   adding: gpf/18/receptor.maps.fld (deflated 65%)
#   adding: gpf/18/receptor.C.map (deflated 59%)
#   adding: gpf/18/receptor.d.map (deflated 72%)
#   adding: gpf/18/receptor.OA.map (deflated 62%)
#   adding: gpf/18/ligand.pdbqt (deflated 70%)
#   adding: gpf/18/receptor.pdbqt (deflated 73%)
#   adding: gpf/18/receptor.glg (deflated 85%)
#   adding: gpf/18/receptor.NA.map (deflated 61%)
#   adding: gpf/18/receptor.N.map (deflated 61%)
#   adding: gpf/18/receptor.e.map (deflated 73%)
#   adding: gpf/18/receptor.maps.xyz (deflated 7%)
#   adding: gpf/18/receptor.A.map (deflated 59%)
#   adding: gpf/18/receptor.HD.map (deflated 71%)
#   adding: gpf/25/ (stored 0%)
#   adding: gpf/25/receptor.gpf (deflated 64%)
#   adding: gpf/25/receptor.maps.fld (deflated 65%)
#   adding: gpf/25/receptor.C.map (deflated 57%)
#   adding: gpf/25/receptor.d.map (deflated 72%)
#   adding: gpf/25/receptor.OA.map (deflated 59%)
#   adding: gpf/25/ligand.pdbqt (deflated 70%)
#   adding: gpf/25/receptor.pdbqt (deflated 73%)
#   adding: gpf/25/receptor.glg (deflated 85%)
#   adding: gpf/25/receptor.NA.map (deflated 58%)
#   adding: gpf/25/receptor.N.map (deflated 58%)
#   adding: gpf/25/receptor.e.map (deflated 71%)
#   adding: gpf/25/receptor.maps.xyz (deflated 13%)
#   adding: gpf/25/receptor.A.map (deflated 57%)
#   adding: gpf/25/receptor.HD.map (deflated 66%)
#   adding: gpf/15/ (stored 0%)
#   adding: gpf/15/receptor.gpf (deflated 65%)
#   adding: gpf/15/receptor.maps.fld (deflated 65%)
#   adding: gpf/15/receptor.C.map (deflated 62%)
#   adding: gpf/15/receptor.d.map (deflated 72%)
#   adding: gpf/15/receptor.OA.map (deflated 65%)
#   adding: gpf/15/ligand.pdbqt (deflated 70%)
#   adding: gpf/15/receptor.pdbqt (deflated 73%)
#   adding: gpf/15/receptor.glg (deflated 85%)
#   adding: gpf/15/receptor.NA.map (deflated 64%)
#   adding: gpf/15/receptor.N.map (deflated 64%)
#   adding: gpf/15/receptor.e.map (deflated 74%)
#   adding: gpf/15/receptor.maps.xyz (deflated 7%)
#   adding: gpf/15/receptor.A.map (deflated 62%)
#   adding: gpf/15/receptor.HD.map (deflated 76%)
#   adding: gpf/56/ (stored 0%)
#   adding: gpf/56/receptor.gpf (deflated 64%)
#   adding: gpf/56/receptor.maps.fld (deflated 65%)
#   adding: gpf/56/receptor.C.map (deflated 57%)
#   adding: gpf/56/receptor.d.map (deflated 71%)
#   adding: gpf/56/receptor.OA.map (deflated 57%)
#   adding: gpf/56/ligand.pdbqt (deflated 70%)
#   adding: gpf/56/receptor.pdbqt (deflated 73%)
#   adding: gpf/56/receptor.glg (deflated 85%)
#   adding: gpf/56/receptor.NA.map (deflated 57%)
#   adding: gpf/56/receptor.N.map (deflated 57%)
#   adding: gpf/56/receptor.e.map (deflated 67%)
#   adding: gpf/56/receptor.maps.xyz (deflated 13%)
#   adding: gpf/56/receptor.A.map (deflated 57%)
#   adding: gpf/56/receptor.HD.map (deflated 63%)
#   adding: gpf/41/ (stored 0%)
#   adding: gpf/41/receptor.gpf (deflated 64%)
#   adding: gpf/41/receptor.maps.fld (deflated 65%)
#   adding: gpf/41/receptor.C.map (deflated 56%)
#   adding: gpf/41/receptor.d.map (deflated 72%)
#   adding: gpf/41/receptor.OA.map (deflated 56%)
#   adding: gpf/41/ligand.pdbqt (deflated 70%)
#   adding: gpf/41/receptor.pdbqt (deflated 73%)
#   adding: gpf/41/receptor.glg (deflated 85%)
#   adding: gpf/41/receptor.NA.map (deflated 56%)
#   adding: gpf/41/receptor.N.map (deflated 56%)
#   adding: gpf/41/receptor.e.map (deflated 67%)
#   adding: gpf/41/receptor.maps.xyz (deflated 13%)
#   adding: gpf/41/receptor.A.map (deflated 56%)
#   adding: gpf/41/receptor.HD.map (deflated 61%)
#   adding: gpf/26/ (stored 0%)
#   adding: gpf/26/receptor.gpf (deflated 64%)
#   adding: gpf/26/receptor.maps.fld (deflated 65%)
#   adding: gpf/26/receptor.C.map (deflated 56%)
#   adding: gpf/26/receptor.d.map (deflated 72%)
#   adding: gpf/26/receptor.OA.map (deflated 58%)
#   adding: gpf/26/ligand.pdbqt (deflated 70%)
#   adding: gpf/26/receptor.pdbqt (deflated 73%)
#   adding: gpf/26/receptor.glg (deflated 85%)
#   adding: gpf/26/receptor.NA.map (deflated 57%)
#   adding: gpf/26/receptor.N.map (deflated 57%)
#   adding: gpf/26/receptor.e.map (deflated 70%)
#   adding: gpf/26/receptor.maps.xyz (deflated 5%)
#   adding: gpf/26/receptor.A.map (deflated 56%)
#   adding: gpf/26/receptor.HD.map (deflated 65%)
#   adding: gpf/34/ (stored 0%)
#   adding: gpf/34/receptor.gpf (deflated 64%)
#   adding: gpf/34/receptor.maps.fld (deflated 65%)
#   adding: gpf/34/receptor.C.map (deflated 56%)
#   adding: gpf/34/receptor.d.map (deflated 72%)
#   adding: gpf/34/receptor.OA.map (deflated 57%)
#   adding: gpf/34/ligand.pdbqt (deflated 70%)
#   adding: gpf/34/receptor.pdbqt (deflated 73%)
#   adding: gpf/34/receptor.glg (deflated 85%)
#   adding: gpf/34/receptor.NA.map (deflated 56%)
#   adding: gpf/34/receptor.N.map (deflated 56%)
#   adding: gpf/34/receptor.e.map (deflated 68%)
#   adding: gpf/34/receptor.maps.xyz (deflated 3%)
#   adding: gpf/34/receptor.A.map (deflated 56%)
#   adding: gpf/34/receptor.HD.map (deflated 62%)
#   adding: gpf/65/ (stored 0%)
#   adding: gpf/65/receptor.gpf (deflated 64%)
#   adding: gpf/65/receptor.maps.fld (deflated 65%)
#   adding: gpf/65/receptor.C.map (deflated 57%)
#   adding: gpf/65/receptor.d.map (deflated 71%)
#   adding: gpf/65/receptor.OA.map (deflated 58%)
#   adding: gpf/65/ligand.pdbqt (deflated 70%)
#   adding: gpf/65/receptor.pdbqt (deflated 73%)
#   adding: gpf/65/receptor.glg (deflated 85%)
#   adding: gpf/65/receptor.NA.map (deflated 58%)
#   adding: gpf/65/receptor.N.map (deflated 58%)
#   adding: gpf/65/receptor.e.map (deflated 67%)
#   adding: gpf/65/receptor.maps.xyz (deflated 8%)
#   adding: gpf/65/receptor.A.map (deflated 57%)
#   adding: gpf/65/receptor.HD.map (deflated 64%)
#   adding: gpf/32/ (stored 0%)
#   adding: gpf/32/receptor.gpf (deflated 64%)
#   adding: gpf/32/receptor.maps.fld (deflated 65%)
#   adding: gpf/32/receptor.C.map (deflated 56%)
#   adding: gpf/32/receptor.d.map (deflated 72%)
#   adding: gpf/32/receptor.OA.map (deflated 57%)
#   adding: gpf/32/ligand.pdbqt (deflated 70%)
#   adding: gpf/32/receptor.pdbqt (deflated 73%)
#   adding: gpf/32/receptor.glg (deflated 85%)
#   adding: gpf/32/receptor.NA.map (deflated 56%)
#   adding: gpf/32/receptor.N.map (deflated 56%)
#   adding: gpf/32/receptor.e.map (deflated 68%)
#   adding: gpf/32/receptor.maps.xyz (deflated 13%)
#   adding: gpf/32/receptor.A.map (deflated 56%)
#   adding: gpf/32/receptor.HD.map (deflated 62%)
#   adding: gpf/44/ (stored 0%)
#   adding: gpf/44/receptor.gpf (deflated 64%)
#   adding: gpf/44/receptor.maps.fld (deflated 65%)
#   adding: gpf/44/receptor.C.map (deflated 56%)
#   adding: gpf/44/receptor.d.map (deflated 72%)
#   adding: gpf/44/receptor.OA.map (deflated 57%)
#   adding: gpf/44/ligand.pdbqt (deflated 70%)
#   adding: gpf/44/receptor.pdbqt (deflated 73%)
#   adding: gpf/44/receptor.glg (deflated 85%)
#   adding: gpf/44/receptor.NA.map (deflated 56%)
#   adding: gpf/44/receptor.N.map (deflated 56%)
#   adding: gpf/44/receptor.e.map (deflated 67%)
#   adding: gpf/44/receptor.maps.xyz (stored 0%)
#   adding: gpf/44/receptor.A.map (deflated 56%)
#   adding: gpf/44/receptor.HD.map (deflated 61%)
#   adding: gpf/40/ (stored 0%)
#   adding: gpf/40/receptor.gpf (deflated 64%)
#   adding: gpf/40/receptor.maps.fld (deflated 65%)
#   adding: gpf/40/receptor.C.map (deflated 56%)
#   adding: gpf/40/receptor.d.map (deflated 72%)
#   adding: gpf/40/receptor.OA.map (deflated 56%)
#   adding: gpf/40/ligand.pdbqt (deflated 70%)
#   adding: gpf/40/receptor.pdbqt (deflated 73%)
#   adding: gpf/40/receptor.glg (deflated 85%)
#   adding: gpf/40/receptor.NA.map (deflated 56%)
#   adding: gpf/40/receptor.N.map (deflated 56%)
#   adding: gpf/40/receptor.e.map (deflated 67%)
#   adding: gpf/40/receptor.maps.xyz (deflated 13%)
#   adding: gpf/40/receptor.A.map (deflated 56%)
#   adding: gpf/40/receptor.HD.map (deflated 61%)
#   adding: gpf/33/ (stored 0%)
#   adding: gpf/33/receptor.gpf (deflated 64%)
#   adding: gpf/33/receptor.maps.fld (deflated 65%)
#   adding: gpf/33/receptor.C.map (deflated 56%)
#   adding: gpf/33/receptor.d.map (deflated 72%)
#   adding: gpf/33/receptor.OA.map (deflated 57%)
#   adding: gpf/33/ligand.pdbqt (deflated 70%)
#   adding: gpf/33/receptor.pdbqt (deflated 73%)
#   adding: gpf/33/receptor.glg (deflated 85%)
#   adding: gpf/33/receptor.NA.map (deflated 56%)
#   adding: gpf/33/receptor.N.map (deflated 56%)
#   adding: gpf/33/receptor.e.map (deflated 68%)
#   adding: gpf/33/receptor.maps.xyz (deflated 13%)
#   adding: gpf/33/receptor.A.map (deflated 56%)
#   adding: gpf/33/receptor.HD.map (deflated 62%)
#   adding: gpf/16/ (stored 0%)
#   adding: gpf/16/receptor.gpf (deflated 64%)
#   adding: gpf/16/receptor.maps.fld (deflated 65%)
#   adding: gpf/16/receptor.C.map (deflated 60%)
#   adding: gpf/16/receptor.d.map (deflated 72%)
#   adding: gpf/16/receptor.OA.map (deflated 63%)
#   adding: gpf/16/ligand.pdbqt (deflated 70%)
#   adding: gpf/16/receptor.pdbqt (deflated 73%)
#   adding: gpf/16/receptor.glg (deflated 85%)
#   adding: gpf/16/receptor.NA.map (deflated 62%)
#   adding: gpf/16/receptor.N.map (deflated 62%)
#   adding: gpf/16/receptor.e.map (deflated 74%)
#   adding: gpf/16/receptor.maps.xyz (deflated 17%)
#   adding: gpf/16/receptor.A.map (deflated 60%)
#   adding: gpf/16/receptor.HD.map (deflated 74%)
#   adding: gpf/63/ (stored 0%)
#   adding: gpf/63/receptor.gpf (deflated 64%)
#   adding: gpf/63/receptor.maps.fld (deflated 65%)
#   adding: gpf/63/receptor.C.map (deflated 57%)
#   adding: gpf/63/receptor.d.map (deflated 71%)
#   adding: gpf/63/receptor.OA.map (deflated 58%)
#   adding: gpf/63/ligand.pdbqt (deflated 70%)
#   adding: gpf/63/receptor.pdbqt (deflated 73%)
#   adding: gpf/63/receptor.glg (deflated 85%)
#   adding: gpf/63/receptor.NA.map (deflated 58%)
#   adding: gpf/63/receptor.N.map (deflated 58%)
#   adding: gpf/63/receptor.e.map (deflated 67%)
#   adding: gpf/63/receptor.maps.xyz (stored 0%)
#   adding: gpf/63/receptor.A.map (deflated 57%)
#   adding: gpf/63/receptor.HD.map (deflated 64%)
#   adding: gpf/48/ (stored 0%)
#   adding: gpf/48/receptor.gpf (deflated 64%)
#   adding: gpf/48/receptor.maps.fld (deflated 65%)
#   adding: gpf/48/receptor.C.map (deflated 56%)
#   adding: gpf/48/receptor.d.map (deflated 72%)
#   adding: gpf/48/receptor.OA.map (deflated 57%)
#   adding: gpf/48/ligand.pdbqt (deflated 70%)
#   adding: gpf/48/receptor.pdbqt (deflated 73%)
#   adding: gpf/48/receptor.glg (deflated 85%)
#   adding: gpf/48/receptor.NA.map (deflated 56%)
#   adding: gpf/48/receptor.N.map (deflated 56%)
#   adding: gpf/48/receptor.e.map (deflated 67%)
#   adding: gpf/48/receptor.maps.xyz (deflated 13%)
#   adding: gpf/48/receptor.A.map (deflated 56%)
#   adding: gpf/48/receptor.HD.map (deflated 62%)
#   adding: gpf/57/ (stored 0%)
#   adding: gpf/57/receptor.gpf (deflated 64%)
#   adding: gpf/57/receptor.maps.fld (deflated 65%)
#   adding: gpf/57/receptor.C.map (deflated 57%)
#   adding: gpf/57/receptor.d.map (deflated 71%)
#   adding: gpf/57/receptor.OA.map (deflated 57%)
#   adding: gpf/57/ligand.pdbqt (deflated 70%)
#   adding: gpf/57/receptor.pdbqt (deflated 73%)
#   adding: gpf/57/receptor.glg (deflated 85%)
#   adding: gpf/57/receptor.NA.map (deflated 57%)
#   adding: gpf/57/receptor.N.map (deflated 57%)
#   adding: gpf/57/receptor.e.map (deflated 67%)
#   adding: gpf/57/receptor.maps.xyz (deflated 13%)
#   adding: gpf/57/receptor.A.map (deflated 57%)
#   adding: gpf/57/receptor.HD.map (deflated 63%)
#   adding: gpf/42/ (stored 0%)
#   adding: gpf/42/receptor.gpf (deflated 64%)
#   adding: gpf/42/receptor.maps.fld (deflated 65%)
#   adding: gpf/42/receptor.C.map (deflated 56%)
#   adding: gpf/42/receptor.d.map (deflated 72%)
#   adding: gpf/42/receptor.OA.map (deflated 56%)
#   adding: gpf/42/ligand.pdbqt (deflated 70%)
#   adding: gpf/42/receptor.pdbqt (deflated 73%)
#   adding: gpf/42/receptor.glg (deflated 85%)
#   adding: gpf/42/receptor.NA.map (deflated 56%)
#   adding: gpf/42/receptor.N.map (deflated 56%)
#   adding: gpf/42/receptor.e.map (deflated 67%)
#   adding: gpf/42/receptor.maps.xyz (deflated 3%)
#   adding: gpf/42/receptor.A.map (deflated 56%)
#   adding: gpf/42/receptor.HD.map (deflated 61%)
#   adding: gpf/60/ (stored 0%)
#   adding: gpf/60/receptor.gpf (deflated 64%)
#   adding: gpf/60/receptor.maps.fld (deflated 65%)
#   adding: gpf/60/receptor.C.map (deflated 57%)
#   adding: gpf/60/receptor.d.map (deflated 71%)
#   adding: gpf/60/receptor.OA.map (deflated 58%)
#   adding: gpf/60/ligand.pdbqt (deflated 70%)
#   adding: gpf/60/receptor.pdbqt (deflated 73%)
#   adding: gpf/60/receptor.glg (deflated 85%)
#   adding: gpf/60/receptor.NA.map (deflated 58%)
#   adding: gpf/60/receptor.N.map (deflated 58%)
#   adding: gpf/60/receptor.e.map (deflated 67%)
#   adding: gpf/60/receptor.maps.xyz (deflated 3%)
#   adding: gpf/60/receptor.A.map (deflated 57%)
#   adding: gpf/60/receptor.HD.map (deflated 63%)
#   adding: gpf/52/ (stored 0%)
#   adding: gpf/52/receptor.gpf (deflated 64%)
#   adding: gpf/52/receptor.maps.fld (deflated 65%)
#   adding: gpf/52/receptor.C.map (deflated 56%)
#   adding: gpf/52/receptor.d.map (deflated 71%)
#   adding: gpf/52/receptor.OA.map (deflated 57%)
#   adding: gpf/52/ligand.pdbqt (deflated 70%)
#   adding: gpf/52/receptor.pdbqt (deflated 73%)
#   adding: gpf/52/receptor.glg (deflated 85%)
#   adding: gpf/52/receptor.NA.map (deflated 57%)
#   adding: gpf/52/receptor.N.map (deflated 57%)
#   adding: gpf/52/receptor.e.map (deflated 66%)
#   adding: gpf/52/receptor.maps.xyz (deflated 3%)
#   adding: gpf/52/receptor.A.map (deflated 56%)
#   adding: gpf/52/receptor.HD.map (deflated 62%)
#   adding: gpf/49/ (stored 0%)
#   adding: gpf/49/receptor.gpf (deflated 64%)
#   adding: gpf/49/receptor.maps.fld (deflated 65%)
#   adding: gpf/49/receptor.C.map (deflated 56%)
#   adding: gpf/49/receptor.d.map (deflated 72%)
#   adding: gpf/49/receptor.OA.map (deflated 57%)
#   adding: gpf/49/ligand.pdbqt (deflated 70%)
#   adding: gpf/49/receptor.pdbqt (deflated 73%)
#   adding: gpf/49/receptor.glg (deflated 85%)
#   adding: gpf/49/receptor.NA.map (deflated 56%)
#   adding: gpf/49/receptor.N.map (deflated 56%)
#   adding: gpf/49/receptor.e.map (deflated 67%)
#   adding: gpf/49/receptor.maps.xyz (deflated 13%)
#   adding: gpf/49/receptor.A.map (deflated 56%)
#   adding: gpf/49/receptor.HD.map (deflated 62%)
#   adding: gpf/43/ (stored 0%)
#   adding: gpf/43/receptor.gpf (deflated 64%)
#   adding: gpf/43/receptor.maps.fld (deflated 65%)
#   adding: gpf/43/receptor.C.map (deflated 56%)
#   adding: gpf/43/receptor.d.map (deflated 72%)
#   adding: gpf/43/receptor.OA.map (deflated 56%)
#   adding: gpf/43/ligand.pdbqt (deflated 70%)
#   adding: gpf/43/receptor.pdbqt (deflated 73%)
#   adding: gpf/43/receptor.glg (deflated 85%)
#   adding: gpf/43/receptor.NA.map (deflated 56%)
#   adding: gpf/43/receptor.N.map (deflated 56%)
#   adding: gpf/43/receptor.e.map (deflated 67%)
#   adding: gpf/43/receptor.maps.xyz (deflated 3%)
#   adding: gpf/43/receptor.A.map (deflated 56%)
#   adding: gpf/43/receptor.HD.map (deflated 61%)
#   adding: gpf/61/ (stored 0%)
#   adding: gpf/61/receptor.gpf (deflated 64%)
#   adding: gpf/61/receptor.maps.fld (deflated 65%)
#   adding: gpf/61/receptor.C.map (deflated 57%)
#   adding: gpf/61/receptor.d.map (deflated 71%)
#   adding: gpf/61/receptor.OA.map (deflated 58%)
#   adding: gpf/61/ligand.pdbqt (deflated 70%)
#   adding: gpf/61/receptor.pdbqt (deflated 73%)
#   adding: gpf/61/receptor.glg (deflated 85%)
#   adding: gpf/61/receptor.NA.map (deflated 58%)
#   adding: gpf/61/receptor.N.map (deflated 58%)
#   adding: gpf/61/receptor.e.map (deflated 67%)
#   adding: gpf/61/receptor.maps.xyz (deflated 3%)
#   adding: gpf/61/receptor.A.map (deflated 57%)
#   adding: gpf/61/receptor.HD.map (deflated 63%)
#   adding: gpf/36/ (stored 0%)
#   adding: gpf/36/receptor.gpf (deflated 64%)
#   adding: gpf/36/receptor.maps.fld (deflated 65%)
#   adding: gpf/36/receptor.C.map (deflated 56%)
#   adding: gpf/36/receptor.d.map (deflated 72%)
#   adding: gpf/36/receptor.OA.map (deflated 56%)
#   adding: gpf/36/ligand.pdbqt (deflated 70%)
#   adding: gpf/36/receptor.pdbqt (deflated 73%)
#   adding: gpf/36/receptor.glg (deflated 85%)
#   adding: gpf/36/receptor.NA.map (deflated 56%)
#   adding: gpf/36/receptor.N.map (deflated 56%)
#   adding: gpf/36/receptor.e.map (deflated 67%)
#   adding: gpf/36/receptor.maps.xyz (deflated 3%)
#   adding: gpf/36/receptor.A.map (deflated 56%)
#   adding: gpf/36/receptor.HD.map (deflated 62%)
#   adding: gpf/28/ (stored 0%)
#   adding: gpf/28/receptor.gpf (deflated 64%)
#   adding: gpf/28/receptor.maps.fld (deflated 65%)
#   adding: gpf/28/receptor.C.map (deflated 56%)
#   adding: gpf/28/receptor.d.map (deflated 72%)
#   adding: gpf/28/receptor.OA.map (deflated 57%)
#   adding: gpf/28/ligand.pdbqt (deflated 70%)
#   adding: gpf/28/receptor.pdbqt (deflated 73%)
#   adding: gpf/28/receptor.glg (deflated 85%)
#   adding: gpf/28/receptor.NA.map (deflated 57%)
#   adding: gpf/28/receptor.N.map (deflated 57%)
#   adding: gpf/28/receptor.e.map (deflated 69%)
#   adding: gpf/28/receptor.maps.xyz (deflated 5%)
#   adding: gpf/28/receptor.A.map (deflated 56%)
#   adding: gpf/28/receptor.HD.map (deflated 64%)
#   adding: gpf/46/ (stored 0%)
#   adding: gpf/46/receptor.gpf (deflated 64%)
#   adding: gpf/46/receptor.maps.fld (deflated 65%)
#   adding: gpf/46/receptor.C.map (deflated 56%)
#   adding: gpf/46/receptor.d.map (deflated 72%)
#   adding: gpf/46/receptor.OA.map (deflated 57%)
#   adding: gpf/46/ligand.pdbqt (deflated 70%)
#   adding: gpf/46/receptor.pdbqt (deflated 73%)
#   adding: gpf/46/receptor.glg (deflated 85%)
#   adding: gpf/46/receptor.NA.map (deflated 56%)
#   adding: gpf/46/receptor.N.map (deflated 56%)
#   adding: gpf/46/receptor.e.map (deflated 67%)
#   adding: gpf/46/receptor.maps.xyz (deflated 3%)
#   adding: gpf/46/receptor.A.map (deflated 56%)
#   adding: gpf/46/receptor.HD.map (deflated 62%)
#   adding: gpf/62/ (stored 0%)
#   adding: gpf/62/receptor.gpf (deflated 64%)
#   adding: gpf/62/receptor.maps.fld (deflated 65%)
#   adding: gpf/62/receptor.C.map (deflated 57%)
#   adding: gpf/62/receptor.d.map (deflated 71%)
#   adding: gpf/62/receptor.OA.map (deflated 58%)
#   adding: gpf/62/ligand.pdbqt (deflated 70%)
#   adding: gpf/62/receptor.pdbqt (deflated 73%)
#   adding: gpf/62/receptor.glg (deflated 85%)
#   adding: gpf/62/receptor.NA.map (deflated 58%)
#   adding: gpf/62/receptor.N.map (deflated 58%)
#   adding: gpf/62/receptor.e.map (deflated 67%)
#   adding: gpf/62/receptor.maps.xyz (stored 0%)
#   adding: gpf/62/receptor.A.map (deflated 57%)
#   adding: gpf/62/receptor.HD.map (deflated 64%)
#   adding: gpf/54/ (stored 0%)
#   adding: gpf/54/receptor.gpf (deflated 64%)
#   adding: gpf/54/receptor.maps.fld (deflated 65%)
#   adding: gpf/54/receptor.C.map (deflated 56%)
#   adding: gpf/54/receptor.d.map (deflated 71%)
#   adding: gpf/54/receptor.OA.map (deflated 57%)
#   adding: gpf/54/ligand.pdbqt (deflated 70%)
#   adding: gpf/54/receptor.pdbqt (deflated 73%)
#   adding: gpf/54/receptor.glg (deflated 85%)
#   adding: gpf/54/receptor.NA.map (deflated 57%)
#   adding: gpf/54/receptor.N.map (deflated 57%)
#   adding: gpf/54/receptor.e.map (deflated 67%)
#   adding: gpf/54/receptor.maps.xyz (deflated 3%)
#   adding: gpf/54/receptor.A.map (deflated 56%)
#   adding: gpf/54/receptor.HD.map (deflated 63%)
#   adding: gpf/21/ (stored 0%)
#   adding: gpf/21/receptor.gpf (deflated 64%)
#   adding: gpf/21/receptor.maps.fld (deflated 65%)
#   adding: gpf/21/receptor.C.map (deflated 58%)
#   adding: gpf/21/receptor.d.map (deflated 72%)
#   adding: gpf/21/receptor.OA.map (deflated 61%)
#   adding: gpf/21/ligand.pdbqt (deflated 70%)
#   adding: gpf/21/receptor.pdbqt (deflated 73%)
#   adding: gpf/21/receptor.glg (deflated 85%)
#   adding: gpf/21/receptor.NA.map (deflated 60%)
#   adding: gpf/21/receptor.N.map (deflated 60%)
#   adding: gpf/21/receptor.e.map (deflated 72%)
#   adding: gpf/21/receptor.maps.xyz (deflated 5%)
#   adding: gpf/21/receptor.A.map (deflated 58%)
#   adding: gpf/21/receptor.HD.map (deflated 69%)
#   adding: ligand.pdbqt (deflated 70%)
#   adding: ligand.sdf (deflated 82%)
#   adding: receptor.pdb (deflated 76%)
#   adding: receptor.pdbqt (deflated 73%)
#   adding: result/ (stored 0%)
#   adding: result/59/ (stored 0%)
#   adding: result/59/gridbox_x59_y59_z59.dlg (deflated 92%)
#   adding: result/59/gridbox_x59_y59_z59.xml (deflated 88%)
#   adding: result/59/gridbox_x59_y59_z59.pdbqt (deflated 70%)
#   adding: result/59/gridbox_x59_y59_z59.sdf (deflated 77%)
#   adding: result/29/ (stored 0%)
#   adding: result/29/gridbox_x29_y29_z29.xml (deflated 88%)
#   adding: result/29/gridbox_x29_y29_z29.pdbqt (deflated 70%)
#   adding: result/29/gridbox_x29_y29_z29.sdf (deflated 76%)
#   adding: result/29/gridbox_x29_y29_z29.dlg (deflated 92%)
#   adding: result/19/ (stored 0%)
#   adding: result/19/gridbox_x19_y19_z19.pdbqt (deflated 69%)
#   adding: result/19/gridbox_x19_y19_z19.sdf (deflated 76%)
#   adding: result/19/gridbox_x19_y19_z19.dlg (deflated 89%)
#   adding: result/19/gridbox_x19_y19_z19.xml (deflated 84%)
#   adding: result/64/ (stored 0%)
#   adding: result/64/gridbox_x64_y64_z64.pdbqt (deflated 70%)
#   adding: result/64/gridbox_x64_y64_z64.xml (deflated 87%)
#   adding: result/64/gridbox_x64_y64_z64.dlg (deflated 92%)
#   adding: result/64/gridbox_x64_y64_z64.sdf (deflated 77%)
#   adding: result/27/ (stored 0%)
#   adding: result/27/gridbox_x27_y27_z27.sdf (deflated 77%)
#   adding: result/27/gridbox_x27_y27_z27.xml (deflated 87%)
#   adding: result/27/gridbox_x27_y27_z27.dlg (deflated 92%)
#   adding: result/27/gridbox_x27_y27_z27.pdbqt (deflated 70%)
#   adding: result/24/ (stored 0%)
#   adding: result/24/gridbox_x24_y24_z24.dlg (deflated 92%)
#   adding: result/24/gridbox_x24_y24_z24.sdf (deflated 76%)
#   adding: result/24/gridbox_x24_y24_z24.pdbqt (deflated 70%)
#   adding: result/24/gridbox_x24_y24_z24.xml (deflated 87%)
#   adding: result/30/ (stored 0%)
#   adding: result/30/gridbox_x30_y30_z30.pdbqt (deflated 70%)
#   adding: result/30/gridbox_x30_y30_z30.xml (deflated 88%)
#   adding: result/30/gridbox_x30_y30_z30.sdf (deflated 77%)
#   adding: result/30/gridbox_x30_y30_z30.dlg (deflated 92%)
#   adding: result/31/ (stored 0%)
#   adding: result/31/gridbox_x31_y31_z31.xml (deflated 88%)
#   adding: result/31/gridbox_x31_y31_z31.dlg (deflated 92%)
#   adding: result/31/gridbox_x31_y31_z31.pdbqt (deflated 70%)
#   adding: result/31/gridbox_x31_y31_z31.sdf (deflated 76%)
#   adding: result/58/ (stored 0%)
#   adding: result/58/gridbox_x58_y58_z58.sdf (deflated 76%)
#   adding: result/58/gridbox_x58_y58_z58.pdbqt (deflated 70%)
#   adding: result/58/gridbox_x58_y58_z58.xml (deflated 88%)
#   adding: result/58/gridbox_x58_y58_z58.dlg (deflated 92%)
#   adding: result/17/ (stored 0%)
#   adding: result/17/gridbox_x17_y17_z17.pdbqt (deflated 70%)
#   adding: result/17/gridbox_x17_y17_z17.sdf (deflated 77%)
#   adding: result/17/gridbox_x17_y17_z17.xml (deflated 84%)
#   adding: result/17/gridbox_x17_y17_z17.dlg (deflated 89%)
#   adding: result/47/ (stored 0%)
#   adding: result/47/gridbox_x47_y47_z47.sdf (deflated 76%)
#   adding: result/47/gridbox_x47_y47_z47.pdbqt (deflated 70%)
#   adding: result/47/gridbox_x47_y47_z47.dlg (deflated 92%)
#   adding: result/47/gridbox_x47_y47_z47.xml (deflated 88%)
#   adding: result/45/ (stored 0%)
#   adding: result/45/gridbox_x45_y45_z45.pdbqt (deflated 70%)
#   adding: result/45/gridbox_x45_y45_z45.xml (deflated 88%)
#   adding: result/45/gridbox_x45_y45_z45.sdf (deflated 76%)
#   adding: result/45/gridbox_x45_y45_z45.dlg (deflated 93%)
#   adding: result/22/ (stored 0%)
#   adding: result/22/gridbox_x22_y22_z22.sdf (deflated 77%)
#   adding: result/22/gridbox_x22_y22_z22.pdbqt (deflated 70%)
#   adding: result/22/gridbox_x22_y22_z22.xml (deflated 86%)
#   adding: result/22/gridbox_x22_y22_z22.dlg (deflated 91%)
#   adding: result/51/ (stored 0%)
#   adding: result/51/gridbox_x51_y51_z51.sdf (deflated 77%)
#   adding: result/51/gridbox_x51_y51_z51.pdbqt (deflated 70%)
#   adding: result/51/gridbox_x51_y51_z51.xml (deflated 88%)
#   adding: result/51/gridbox_x51_y51_z51.dlg (deflated 93%)
#   adding: result/50/ (stored 0%)
#   adding: result/50/gridbox_x50_y50_z50.sdf (deflated 77%)
#   adding: result/50/gridbox_x50_y50_z50.dlg (deflated 92%)
#   adding: result/50/gridbox_x50_y50_z50.pdbqt (deflated 70%)
#   adding: result/50/gridbox_x50_y50_z50.xml (deflated 88%)
#   adding: result/37/ (stored 0%)
#   adding: result/37/gridbox_x37_y37_z37.pdbqt (deflated 70%)
#   adding: result/37/gridbox_x37_y37_z37.sdf (deflated 77%)
#   adding: result/37/gridbox_x37_y37_z37.dlg (deflated 93%)
#   adding: result/37/gridbox_x37_y37_z37.xml (deflated 88%)
#   adding: result/20/ (stored 0%)
#   adding: result/20/gridbox_x20_y20_z20.xml (deflated 85%)
#   adding: result/20/gridbox_x20_y20_z20.dlg (deflated 90%)
#   adding: result/20/gridbox_x20_y20_z20.pdbqt (deflated 70%)
#   adding: result/20/gridbox_x20_y20_z20.sdf (deflated 76%)
#   adding: result/55/ (stored 0%)
#   adding: result/55/gridbox_x55_y55_z55.pdbqt (deflated 70%)
#   adding: result/55/gridbox_x55_y55_z55.dlg (deflated 93%)
#   adding: result/55/gridbox_x55_y55_z55.xml (deflated 88%)
#   adding: result/55/gridbox_x55_y55_z55.sdf (deflated 77%)
#   adding: result/35/ (stored 0%)
#   adding: result/35/gridbox_x35_y35_z35.sdf (deflated 77%)
#   adding: result/35/gridbox_x35_y35_z35.pdbqt (deflated 70%)
#   adding: result/35/gridbox_x35_y35_z35.dlg (deflated 93%)
#   adding: result/35/gridbox_x35_y35_z35.xml (deflated 88%)
#   adding: result/53/ (stored 0%)
#   adding: result/53/gridbox_x53_y53_z53.dlg (deflated 93%)
#   adding: result/53/gridbox_x53_y53_z53.sdf (deflated 77%)
#   adding: result/53/gridbox_x53_y53_z53.xml (deflated 88%)
#   adding: result/53/gridbox_x53_y53_z53.pdbqt (deflated 70%)
#   adding: result/39/ (stored 0%)
#   adding: result/39/gridbox_x39_y39_z39.dlg (deflated 92%)
#   adding: result/39/gridbox_x39_y39_z39.xml (deflated 88%)
#   adding: result/39/gridbox_x39_y39_z39.pdbqt (deflated 70%)
#   adding: result/39/gridbox_x39_y39_z39.sdf (deflated 76%)
#   adding: result/38/ (stored 0%)
#   adding: result/38/gridbox_x38_y38_z38.pdbqt (deflated 70%)
#   adding: result/38/gridbox_x38_y38_z38.sdf (deflated 76%)
#   adding: result/38/gridbox_x38_y38_z38.xml (deflated 88%)
#   adding: result/38/gridbox_x38_y38_z38.dlg (deflated 92%)
#   adding: result/23/ (stored 0%)
#   adding: result/23/gridbox_x23_y23_z23.dlg (deflated 90%)
#   adding: result/23/gridbox_x23_y23_z23.pdbqt (deflated 70%)
#   adding: result/23/gridbox_x23_y23_z23.xml (deflated 86%)
#   adding: result/23/gridbox_x23_y23_z23.sdf (deflated 77%)
#   adding: result/18/ (stored 0%)
#   adding: result/18/gridbox_x18_y18_z18.xml (deflated 84%)
#   adding: result/18/gridbox_x18_y18_z18.dlg (deflated 89%)
#   adding: result/18/gridbox_x18_y18_z18.pdbqt (deflated 70%)
#   adding: result/18/gridbox_x18_y18_z18.sdf (deflated 77%)
#   adding: result/25/ (stored 0%)
#   adding: result/25/gridbox_x25_y25_z25.dlg (deflated 92%)
#   adding: result/25/gridbox_x25_y25_z25.pdbqt (deflated 70%)
#   adding: result/25/gridbox_x25_y25_z25.xml (deflated 87%)
#   adding: result/25/gridbox_x25_y25_z25.sdf (deflated 76%)
#   adding: result/15/ (stored 0%)
#   adding: result/15/gridbox_x15_y15_z15.pdbqt (deflated 70%)
#   adding: result/15/gridbox_x15_y15_z15.dlg (deflated 89%)
#   adding: result/15/gridbox_x15_y15_z15.xml (deflated 85%)
#   adding: result/15/gridbox_x15_y15_z15.sdf (deflated 77%)
#   adding: result/56/ (stored 0%)
#   adding: result/56/gridbox_x56_y56_z56.dlg (deflated 92%)
#   adding: result/56/gridbox_x56_y56_z56.xml (deflated 88%)
#   adding: result/56/gridbox_x56_y56_z56.sdf (deflated 76%)
#   adding: result/56/gridbox_x56_y56_z56.pdbqt (deflated 70%)
#   adding: result/41/ (stored 0%)
#   adding: result/41/gridbox_x41_y41_z41.dlg (deflated 93%)
#   adding: result/41/gridbox_x41_y41_z41.xml (deflated 88%)
#   adding: result/41/gridbox_x41_y41_z41.sdf (deflated 77%)
#   adding: result/41/gridbox_x41_y41_z41.pdbqt (deflated 70%)
#   adding: result/26/ (stored 0%)
#   adding: result/26/gridbox_x26_y26_z26.xml (deflated 88%)
#   adding: result/26/gridbox_x26_y26_z26.pdbqt (deflated 70%)
#   adding: result/26/gridbox_x26_y26_z26.sdf (deflated 76%)
#   adding: result/26/gridbox_x26_y26_z26.dlg (deflated 92%)
#   adding: result/34/ (stored 0%)
#   adding: result/34/gridbox_x34_y34_z34.pdbqt (deflated 70%)
#   adding: result/34/gridbox_x34_y34_z34.dlg (deflated 93%)
#   adding: result/34/gridbox_x34_y34_z34.sdf (deflated 76%)
#   adding: result/34/gridbox_x34_y34_z34.xml (deflated 88%)
#   adding: result/65/ (stored 0%)
#   adding: result/65/gridbox_x65_y65_z65.dlg (deflated 92%)
#   adding: result/65/gridbox_x65_y65_z65.pdbqt (deflated 70%)
#   adding: result/65/gridbox_x65_y65_z65.sdf (deflated 77%)
#   adding: result/65/gridbox_x65_y65_z65.xml (deflated 88%)
#   adding: result/32/ (stored 0%)
#   adding: result/32/gridbox_x32_y32_z32.xml (deflated 88%)
#   adding: result/32/gridbox_x32_y32_z32.dlg (deflated 93%)
#   adding: result/32/gridbox_x32_y32_z32.pdbqt (deflated 70%)
#   adding: result/32/gridbox_x32_y32_z32.sdf (deflated 76%)
#   adding: result/44/ (stored 0%)
#   adding: result/44/gridbox_x44_y44_z44.pdbqt (deflated 70%)
#   adding: result/44/gridbox_x44_y44_z44.dlg (deflated 93%)
#   adding: result/44/gridbox_x44_y44_z44.sdf (deflated 76%)
#   adding: result/44/gridbox_x44_y44_z44.xml (deflated 88%)
#   adding: result/40/ (stored 0%)
#   adding: result/40/gridbox_x40_y40_z40.sdf (deflated 77%)
#   adding: result/40/gridbox_x40_y40_z40.dlg (deflated 93%)
#   adding: result/40/gridbox_x40_y40_z40.pdbqt (deflated 70%)
#   adding: result/40/gridbox_x40_y40_z40.xml (deflated 88%)
#   adding: result/33/ (stored 0%)
#   adding: result/33/gridbox_x33_y33_z33.dlg (deflated 92%)
#   adding: result/33/gridbox_x33_y33_z33.sdf (deflated 76%)
#   adding: result/33/gridbox_x33_y33_z33.xml (deflated 88%)
#   adding: result/33/gridbox_x33_y33_z33.pdbqt (deflated 70%)
#   adding: result/16/ (stored 0%)
#   adding: result/16/gridbox_x16_y16_z16.xml (deflated 84%)
#   adding: result/16/gridbox_x16_y16_z16.pdbqt (deflated 70%)
#   adding: result/16/gridbox_x16_y16_z16.sdf (deflated 76%)
#   adding: result/16/gridbox_x16_y16_z16.dlg (deflated 89%)
#   adding: result/63/ (stored 0%)
#   adding: result/63/gridbox_x63_y63_z63.dlg (deflated 92%)
#   adding: result/63/gridbox_x63_y63_z63.xml (deflated 87%)
#   adding: result/63/gridbox_x63_y63_z63.sdf (deflated 77%)
#   adding: result/63/gridbox_x63_y63_z63.pdbqt (deflated 70%)
#   adding: result/48/ (stored 0%)
#   adding: result/48/gridbox_x48_y48_z48.pdbqt (deflated 70%)
#   adding: result/48/gridbox_x48_y48_z48.sdf (deflated 77%)
#   adding: result/48/gridbox_x48_y48_z48.xml (deflated 88%)
#   adding: result/48/gridbox_x48_y48_z48.dlg (deflated 92%)
#   adding: result/57/ (stored 0%)
#   adding: result/57/gridbox_x57_y57_z57.sdf (deflated 76%)
#   adding: result/57/gridbox_x57_y57_z57.pdbqt (deflated 70%)
#   adding: result/57/gridbox_x57_y57_z57.xml (deflated 88%)
#   adding: result/57/gridbox_x57_y57_z57.dlg (deflated 92%)
#   adding: result/42/ (stored 0%)
#   adding: result/42/gridbox_x42_y42_z42.pdbqt (deflated 70%)
#   adding: result/42/gridbox_x42_y42_z42.xml (deflated 88%)
#   adding: result/42/gridbox_x42_y42_z42.dlg (deflated 93%)
#   adding: result/42/gridbox_x42_y42_z42.sdf (deflated 76%)
#   adding: result/60/ (stored 0%)
#   adding: result/60/gridbox_x60_y60_z60.sdf (deflated 76%)
#   adding: result/60/gridbox_x60_y60_z60.pdbqt (deflated 70%)
#   adding: result/60/gridbox_x60_y60_z60.dlg (deflated 92%)
#   adding: result/60/gridbox_x60_y60_z60.xml (deflated 88%)
#   adding: result/52/ (stored 0%)
#   adding: result/52/gridbox_x52_y52_z52.sdf (deflated 76%)
#   adding: result/52/gridbox_x52_y52_z52.pdbqt (deflated 70%)
#   adding: result/52/gridbox_x52_y52_z52.dlg (deflated 92%)
#   adding: result/52/gridbox_x52_y52_z52.xml (deflated 88%)
#   adding: result/49/ (stored 0%)
#   adding: result/49/gridbox_x49_y49_z49.pdbqt (deflated 70%)
#   adding: result/49/gridbox_x49_y49_z49.xml (deflated 88%)
#   adding: result/49/gridbox_x49_y49_z49.dlg (deflated 92%)
#   adding: result/49/gridbox_x49_y49_z49.sdf (deflated 77%)
#   adding: result/43/ (stored 0%)
#   adding: result/43/gridbox_x43_y43_z43.pdbqt (deflated 70%)
#   adding: result/43/gridbox_x43_y43_z43.xml (deflated 88%)
#   adding: result/43/gridbox_x43_y43_z43.dlg (deflated 93%)
#   adding: result/43/gridbox_x43_y43_z43.sdf (deflated 77%)
#   adding: result/61/ (stored 0%)
#   adding: result/61/gridbox_x61_y61_z61.sdf (deflated 76%)
#   adding: result/61/gridbox_x61_y61_z61.dlg (deflated 92%)
#   adding: result/61/gridbox_x61_y61_z61.pdbqt (deflated 70%)
#   adding: result/61/gridbox_x61_y61_z61.xml (deflated 88%)
#   adding: result/36/ (stored 0%)
#   adding: result/36/gridbox_x36_y36_z36.pdbqt (deflated 70%)
#   adding: result/36/gridbox_x36_y36_z36.sdf (deflated 77%)
#   adding: result/36/gridbox_x36_y36_z36.xml (deflated 88%)
#   adding: result/36/gridbox_x36_y36_z36.dlg (deflated 92%)
#   adding: result/28/ (stored 0%)
#   adding: result/28/gridbox_x28_y28_z28.dlg (deflated 92%)
#   adding: result/28/gridbox_x28_y28_z28.xml (deflated 88%)
#   adding: result/28/gridbox_x28_y28_z28.pdbqt (deflated 70%)
#   adding: result/28/gridbox_x28_y28_z28.sdf (deflated 77%)
#   adding: result/46/ (stored 0%)
#   adding: result/46/gridbox_x46_y46_z46.sdf (deflated 77%)
#   adding: result/46/gridbox_x46_y46_z46.dlg (deflated 92%)
#   adding: result/46/gridbox_x46_y46_z46.xml (deflated 88%)
#   adding: result/46/gridbox_x46_y46_z46.pdbqt (deflated 70%)
#   adding: result/62/ (stored 0%)
#   adding: result/62/gridbox_x62_y62_z62.xml (deflated 88%)
#   adding: result/62/gridbox_x62_y62_z62.dlg (deflated 92%)
#   adding: result/62/gridbox_x62_y62_z62.pdbqt (deflated 70%)
#   adding: result/62/gridbox_x62_y62_z62.sdf (deflated 76%)
#   adding: result/54/ (stored 0%)
#   adding: result/54/gridbox_x54_y54_z54.pdbqt (deflated 70%)
#   adding: result/54/gridbox_x54_y54_z54.xml (deflated 88%)
#   adding: result/54/gridbox_x54_y54_z54.sdf (deflated 76%)
#   adding: result/54/gridbox_x54_y54_z54.dlg (deflated 92%)
#   adding: result/21/ (stored 0%)
#   adding: result/21/gridbox_x21_y21_z21.pdbqt (deflated 70%)
#   adding: result/21/gridbox_x21_y21_z21.dlg (deflated 90%)
#   adding: result/21/gridbox_x21_y21_z21.xml (deflated 86%)
#   adding: result/21/gridbox_x21_y21_z21.sdf (deflated 76%)
#   adding: RMSD evaluation for each gridbox size.csv (deflated 65%)
